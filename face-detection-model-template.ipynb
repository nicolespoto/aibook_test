# %%
# =====================================
# Face Detection using OpenVINO template
# Programming Exercise 7-2: Face Detection with OpenVINO
# =====================================

import os
import numpy as np
import cv2
import matplotlib.pyplot as plt
from openvino.runtime import Core

# -----------------------------
# Step 1: Display Current Directory
# -----------------------------
# Task: Print your current working directory.
# Expected output: path of your notebook folder

# Hint: use os.getcwd()

# YOUR CODE HERE


# -----------------------------
# Step 2: Verify Model Files Exist
# -----------------------------
# Task: Ensure these model files exist in the folder:
# - face-detection-adas-0001.xml
# - face-detection-adas-0001.bin
# Expected output:
# "Model files found"

# Hint: use os.path.exists()

# YOUR CODE HERE


# -----------------------------
# Step 3: Load Model
# -----------------------------
# Task: Initialize OpenVINO Core runtime and load the model
# Expected output:
# "Model loaded successfully"


# YOUR CODE HERE


# -----------------------------
# Step 4: Compile Model for CPU
# -----------------------------
# Task: Compile the model for CPU inference
# Expected output:
# "Inference engine initialized"


# YOUR CODE HERE


# -----------------------------
# Step 5: Load and Preprocess Image
# -----------------------------
# Task: Load "test_face.jpg", resize it to 672x384
# Convert image from HWC to CHW format
# Expected output:
# "Image preprocessing complete"


# YOUR CODE HERE


# -----------------------------
# Step 6: Run Face Detection Inference
# -----------------------------
# Task: Run the model on the preprocessed image
# Expected output:
# "Running face detection..."
# "Inference completed"


# YOUR CODE HERE


# -----------------------------
# Step 7: Process Detection Results
# -----------------------------
# Task: Loop through inference output
# Count faces above confidence threshold 0.5
# Draw bounding boxes around faces
# Expected output for each detection:
# "Face detected"
# "Confidence: 0.xx"


# YOUR CODE HERE


# -----------------------------
# Step 8: Display Detection Summary
# -----------------------------
# Task: Print a summary report of total detected faces
# Expected output:
# ============================
# Inference Summary Report
# Faces Detected: X
# ============================


# YOUR CODE HERE


# -----------------------------
# Step 9: Visualize Detection Result
# -----------------------------
# Task: Display the annotated image with bounding boxes
# Title: "Face Detection Result"


# YOUR CODE HERE
